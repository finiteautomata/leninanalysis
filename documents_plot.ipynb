# %% [markdown]
# First, let's take all the documents that we take into account

# %%
from interpreter import *
# %pylab inline
import matplotlib.pyplot as plt
from information_value.models import Document, DocumentList
# Gather all the documents
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def plot_length_histogram(docs, title):
    num_tokens = [doc.number_of_words for doc in docs]

    plt.title(title) 
    plt.xlabel("Number of words")
    plt.ylabel("Amount of works")
    plt.hist(num_tokens, bins=30)

# %%
docs = Document.query.find({'number_of_words': {'$gte': 2000, '$lte':20000 }})
plot_length_histogram(docs,
    title="Histogram for works with <20k words")

# %%
docs = Document.query.find({'number_of_words': {'$gte': 20000 }})
plot_length_histogram(docs,
    title="Histogram for works with >20k words")

# %%
# %pylab inline

print db.document.aggregate([
        { "$group" : { "_id": "$year", "number_of_works": {"$sum": 1 } }}
])
# Out:
# Populating the interactive namespace from numpy and matplotlib
# {u'ok': 1.0, u'result': [{u'_id': u'1894', u'number_of_works': 7}, {u'_id': u'1896', u'number_of_works': 6}, {u'_id': u'1909', u'number_of_works': 77}, {u'_id': u'1900', u'number_of_works': 31}, {u'_id': u'1922', u'number_of_works': 111}, {u'_id': u'1902', u'number_of_works': 57}, {u'_id': u'1915', u'number_of_works': 118}, {u'_id': u'1908', u'number_of_works': 78}, {u'_id': u'1912', u'number_of_works': 156}, {u'_id': u'1906', u'number_of_works': 130}, {u'_id': u'1899', u'number_of_works': 26}, {u'_id': u'2013', u'number_of_works': 1}, {u'_id': u'1910', u'number_of_works': 76}, {u'_id': u'1923', u'number_of_works': 8}, {u'_id': u'1907', u'number_of_works': 96}, {u'_id': u'1895', u'number_of_works': 13}, {u'_id': u'1917', u'number_of_works': 428}, {u'_id': u'1898', u'number_of_works': 27}, {u'_id': u'1920', u'number_of_works': 171}, {u'_id': u'1903', u'number_of_works': 60}, {u'_id': u'1897', u'number_of_works': 28}, {u'_id': u'1901', u'number_of_works': 68}, {u'_id': u'1921', u'number_of_works': 160}, {u'_id': u'1916', u'number_of_works': 149}, {u'_id': u'1919', u'number_of_works': 168}, {u'_id': u'1904', u'number_of_works': 105}, {u'_id': u'1893', u'number_of_works': 5}, {u'_id': u'1851', u'number_of_works': 1}, {u'_id': u'1905', u'number_of_works': 257}, {u'_id': u'1911', u'number_of_works': 81}, {u'_id': u'1913', u'number_of_works': 249}, {u'_id': u'1914', u'number_of_works': 189}, {u'_id': u'1918', u'number_of_works': 231}]}
