# %%
from interpreter import *

words =[
          "war", "capitalism", "theory", "toilette",
          "imperialism", "worker", "praxis", "revolution", 
          "money", "philosophy", "idealism", "strategy", "materialism", "lion",
          "television", "hair", "sugar", "tactic", "car"]

synsets = [
           "war.n.01",
           "capitalism.n.01",
           "theory.n.01",
           "toilet.n.04",
           "imperialism.n.02",
           "proletarian.n.01",
           "practice.n.03",
           "revolution.n.01",
           "money.n.01",
           "philosophy.n.02",
           "idealism.n.01",
           "strategy.n.02",
           "materialism.n.02",
           "lion.n.01",
           "television_receiver.n.01",
           "hair.n.01",
           "sugar.n.01",

# %%
def print_synsets(word):
    for synset in wn.synsets(word):
        print "%s - %s" % (synset.name, synset.definition)
        
for word in words:
    print "="*80
    print "* %s *" % word
    print_synsets(word)
# Out:
# ...
# * war *
# war.n.01 - the waging of armed conflict against an enemy
# war.n.02 - a legal state created by a declaration of war and ended by official declaration during which the international rules of war apply
# war.n.03 - an active struggle between competing entities
# war.n.04 - a concerted campaign to end something that is injurious
# war.v.01 - make or wage war
# ...
# * capitalism *
# capitalism.n.01 - an economic system based on private ownership of capital
# ...
# * theory *
# theory.n.01 - a well-substantiated explanation of some aspect of the natural world; an organized system of accepted knowledge that applies in a variety of circumstances to explain a specific set of phenomena
# hypothesis.n.02 - a tentative insight into the natural world; a concept that is not yet verified but that if true would explain certain facts or phenomena
# theory.n.03 - a belief that can guide behavior
# ...
# * toilette *
# toilet.n.04 - the act of dressing and preparing yourself
# ...
# * imperialism *
# ...
